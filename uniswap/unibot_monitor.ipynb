# %%
require 'faraday'
require 'faraday/net_http'
require 'active_support/all'

endpoint = "http://47.74.34.17:54321/history/uniswap_v3/APE-WETH-3000"

data = []
last_id = 0

loop do
    puts last_id

    conn = Faraday.new( url: endpoint+"?start_block=0")
    response = conn.get() do |req|
        req["Authorization"] = "Bearer FWe4Bf3Yg5hd6jFds367SDMiujw204DVs"
    end

    puts JSON.parse(response.body)
    raise "here"

    slice = JSON.parse(response.body)["data"]
    
    break if slice.size==0

    data = data + slice
    
    last_id = slice[-1]["id"]
end

nil
# Out:
# 0
# {"code"=>0, "data"=>[{"block_number"=>14677934, "tick"=>-49049, "ts"=>1651218218}, {"block_number"=>14677935, "tick"=>-49073, "ts"=>1651218255}, {"block_number"=>14677936, "tick"=>-49073, "ts"=>1651218264}, {"block_number"=>14677937, "tick"=>-49073, "ts"=>1651218267}, {"block_number"=>14677938, "tick"=>-49073, "ts"=>1651218270}, {"block_number"=>14677939, "tick"=>-49073, "ts"=>1651218277}, {"block_number"=>14677940, "tick"=>-49073, "ts"=>1651218280}, {"block_number"=>14677941, "tick"=>-49073, "ts"=>1651218282}, {"block_number"=>14677942, "tick"=>-49072, "ts"=>1651218307}, {"block_number"=>14677943, "tick"=>-49070, "ts"=>1651218327}, {"block_number"=>14677944, "tick"=>-49070, "ts"=>1651218333}, {"block_number"=>14677945, "tick"=>-49070, "ts"=>1651218333}, {"block_number"=>14677946, "tick"=>-49070, "ts"=>1651218343}, {"block_number"=>14677948, "tick"=>-49069, "ts"=>1651218348}, {"block_number"=>14677949, "tick"=>-49063, "ts"=>1651218363}, {"block_number"=>14677950, "tick"=>-49053, "ts"=>1651218366}, {"block_number"=>14677951, "tick"=>-49059, "ts"=>1651218398}, {"block_number"=>14677952, "tick"=>-49059, "ts"=>1651218405}, {"block_number"=>14677953, "tick"=>-49050, "ts"=>1651218449}, {"block_number"=>14677954, "tick"=>-49047, "ts"=>1651218452}, {"block_number"=>14677955, "tick"=>-49047, "ts"=>1651218459}, {"block_number"=>14677956, "tick"=>-49047, "ts"=>1651218473}, {"block_number"=>14677957, "tick"=>-49047, "ts"=>1651218482}, {"block_number"=>14677958, "tick"=>-49044, "ts"=>1651218492}, {"block_number"=>14677959, "tick"=>-49044, "ts"=>1651218499}, {"block_number"=>14677960, "tick"=>-49044, "ts"=>1651218508}, {"block_number"=>14677962, "tick"=>-49044, "ts"=>1651218520}, {"block_number"=>14677963, "tick"=>-49044, "ts"=>1651218527}, {"block_number"=>14677964, "tick"=>-49052, "ts"=>1651218567}, {"block_number"=>14677965, "tick"=>-49056, "ts"=>1651218572}, {"block_number"=>14677966, "tick"=>-49055, "ts"=>1651218590}, {"block_number"=>14677967, "tick"=>-49055, "ts"=>1651218602}, {"block_number"=>14677968, "tick"=>-49055, "ts"=>1651218633}, {"block_number"=>14677969, "tick"=>-49057, "ts"=>1651218636}, {"block_number"=>14677970, "tick"=>-49032, "ts"=>1651218656}, {"block_number"=>14677971, "tick"=>-49050, "ts"=>1651218705}, {"block_number"=>14677972, "tick"=>-49050, "ts"=>1651218714}, {"block_number"=>14677973, "tick"=>-49050, "ts"=>1651218719}, {"block_number"=>14677974, "tick"=>-49050, "ts"=>1651218727}, {"block_number"=>14677975, "tick"=>-49050, "ts"=>1651218727}, {"block_number"=>14677977, "tick"=>-49050, "ts"=>1651218739}, {"block_number"=>14677978, "tick"=>-49084, "ts"=>1651218757}, {"block_number"=>14677979, "tick"=>-49084, "ts"=>1651218760}, {"block_number"=>14677980, "tick"=>-49074, "ts"=>1651218763}, {"block_number"=>14677981, "tick"=>-49071, "ts"=>1651218779}, {"block_number"=>14677982, "tick"=>-49071, "ts"=>1651218812}, {"block_number"=>14677983, "tick"=>-49071, "ts"=>1651218815}, {"block_number"=>14677984, "tick"=>-49070, "ts"=>1651218820}, {"block_number"=>14677985, "tick"=>-49070, "ts"=>1651218825}, {"block_number"=>14677986, "tick"=>-49069, "ts"=>1651218839}, {"block_number"=>14677987, "tick"=>-49069, "ts"=>1651218872}, {"block_number"=>14677988, "tick"=>-49057, "ts"=>1651218893}, {"block_number"=>14677989, "tick"=>-49057, "ts"=>1651218895}, {"block_number"=>14677990, "tick"=>-49046, "ts"=>1651218905}, {"block_number"=>14677991, "tick"=>-49046, "ts"=>1651218905}, {"block_number"=>14677992, "tick"=>-49046, "ts"=>1651218910}, {"block_number"=>14677993, "tick"=>-49046, "ts"=>1651218931}, {"block_number"=>14677994, "tick"=>-49034, "ts"=>1651218938}, {"block_number"=>14677995, "tick"=>-49034, "ts"=>1651218958}, {"block_number"=>14677996, "tick"=>-49034, "ts"=>1651219007}, {"block_number"=>14677997, "tick"=>-49033, "ts"=>1651219030}, {"block_number"=>14677998, "tick"=>-49029, "ts"=>1651219039}, {"block_number"=>14678000, "tick"=>-49031, "ts"=>1651219060}, {"block_number"=>14678001, "tick"=>-49031, "ts"=>1651219069}, {"block_num ...
# RuntimeError: here
# (irb):18:in `block in irb_binding'
# (irb):9:in `loop'
# (irb):9:in `irb_binding'

# %%
require 'redis-objects'
require 'connection_pool'

ENV["REDIS_CONNECT_STR"] = "redis://r-0xier2piq63bs2f3ux:tyLt3XkkXY@r-0xier2piq63bs2f3uxpd.redis.rds.aliyuncs.com"
class DataStore
    def self.init
        Redis::Objects.redis = ConnectionPool.new(size: 5, timeout: 5) { Redis.new(ssl_params: {verify_mode: OpenSSL::SSL::VERIFY_NONE},:url => ENV["REDIS_CONNECT_STR"]) }
        @@redis_objects = {}
        nil
    end
    
    def self.redis_object(key)
        return @@redis_objects[key] if @@redis_objects.has_key?(key)
        @@redis_objects[key] = Redis::Value.new(key,:marshal => true, :compress => true)
    end
        
    def self.get (key)
        obj = self.redis_object(key)
        obj.value
    end

    def self.set (key,value)
        obj = self.redis_object(key)
        obj.value=value
    end
    
    def self.delete (key)
        obj = self.redis_object(key)
        obj.delete
    end
end

DataStore.init

# %%
r=Redis.new(url:"redis://r-0xier2piq63bs2f3ux:tyLt3XkkXY@r-0xier2piq63bs2f3uxpd.redis.rds.aliyuncs.com")
# Out:
# #<Redis client v4.6.0 for redis://r-0xier2piq63bs2f3uxpd.redis.rds.aliyuncs.com:6379/0>
# Redis::CommandError: ERR unknown command `to_hash`, with args beginning with:
# /usr/local/bundle/gems/redis-4.6.0/lib/redis/client.rb:162:in `call'
# /usr/local/bundle/gems/redis-4.6.0/lib/redis.rb:263:in `block in send_command'
# /usr/local/bundle/gems/redis-4.6.0/lib/redis.rb:262:in `synchronize'
# /usr/local/bundle/gems/redis-4.6.0/lib/redis.rb:262:in `send_command'
# /usr/local/bundle/gems/redis-4.6.0/lib/redis/commands.rb:239:in `method_missing'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/kernel.rb:221:in `execute_request'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/kernel.rb:139:in `dispatch'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/kernel.rb:127:in `run'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/command.rb:106:in `run_kernel'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/command.rb:37:in `run'
# /usr/local/bundle/gems/iruby-0.7.4/bin/iruby:5:in `<top (required)>'
# /usr/local/bundle/bin/iruby:23:in `load'
# /usr/local/bundle/bin/iruby:23:in `<main>'
# Interrupt:
# /usr/local/bundle/gems/ffi-rzmq-2.0.7/lib/ffi-rzmq/socket.rb:584:in `zmq_recvmsg'
# /usr/local/bundle/gems/ffi-rzmq-2.0.7/lib/ffi-rzmq/socket.rb:584:in `__recvmsg__'
# /usr/local/bundle/gems/ffi-rzmq-2.0.7/lib/ffi-rzmq/socket.rb:321:in `recvmsg'
# /usr/local/bundle/gems/ffi-rzmq-2.0.7/lib/ffi-rzmq/socket.rb:342:in `recv_string'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/session_adapter/ffirzmq_adapter.rb:19:in `recv'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/session.rb:91:in `recv'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/kernel.rb:133:in `dispatch'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/kernel.rb:127:in `run'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/command.rb:106:in `run_kernel'
# /usr/local/bundle/gems/iruby-0.7.4/lib/iruby/command.rb:37:in `run'
# /usr/local/bundle/gems/iruby-0.7.4/bin/iruby:5:in `<top (required)>'
# /usr/local/bundle/bin/iruby:23:in `load'
# /usr/local/bundle/bin/iruby:23:in `<main>'

# %%
Redis::Objects.redis.keys
# Out:
# ["hello-world"]

# %%
DataStore.set("hello-world","hello-world!")
# Out:
# "hello-world!"

# %%
DataStore.get("hello-world")
# Out:
# "hello-world!"

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ebde59c2-d67b-4e31-ad3b-1bdd07014691' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
