", \"18\", \"18\", \"0.01\", \"0.0003\"], [\"AAVE\", \"ETH\", \"0x5ab53ee1d50eef2c1dd3d5402789cd27bb52c1bb\", \"18\", \"18\", \"0.003\", \"0.0003\"], [\"ETH\", \"ACH\", \"0xeb4626c5149894022c2066120ea7f20f217995fb\", \"18\", \"8\", \"0.01\", \"0.0003\"], [\"USDT\", \"ACH\", \"0xbe3cd9b751360a8030770425acf947c8cb4cab38\", \"6\", \"8\", \"0.01\", \"0.0003\"], [\"AGLD\", \"ETH\", \"0x5d752f322befb038991579972e912b02f61a3dda\", \"18\", \"18\", \"0.01\", \"0.0003\"], [\"AKITA\", \"ETH\", \"0xcd9dab5e666de980cecdc180cb31f296733e2587\", \"18\", \"18\", \"0.01\", \"0.0003\"], [\"ALPHA\", \"ETH\", \"0x460d50
# ...

# %%
require 'faraday'
require 'faraday/net_http'
require 'active_support/all'

require 'json'

# all_pools = JSON.parse(pool_data).map { |p| 
#  {
#      pool:p[2],
#      token0:p[0],
#      token1:p[1],
#      token0_decimal:p[3].to_i,
#      token1_decimal:p[4].to_i,
#      dex_fee:p[5].to_f,
#      cex_fee:p[6].to_f,
#  }
# }
# Out:
# false

# %%
require 'redis-objects'
require 'connection_pool'

ENV["REDIS_CONNECT_STR"] = "rediss://:pc227a12029db09ce525cceb0ac452b3c1a2cb2ba538fcc48f540cc4dd92db7e1@ec2-34-224-55-185.compute-1.amazonaws.com:9579"
class DataStore
    def self.init
        Redis::Objects.redis = ConnectionPool.new(size: 5, timeout: 5) { Redis.new(ssl_params: {verify_mode: OpenSSL::SSL::VERIFY_NONE},:url => ENV["REDIS_CONNECT_STR"]) }
        @@redis_objects = {}
        nil
    end
    
    def self.redis_object(key)
        return @@redis_objects[key] if @@redis_objects.has_key?(key)
        @@redis_objects[key] = Redis::Value.new(key,:marshal => true, :compress => true)
    end
        
    def self.get (key)
        obj = self.redis_object(key)
        obj.value
    end

    def self.set (key,value)
        obj = self.redis_object(key)
        obj.value=value
    end
    
    def self.delete (key)
        obj = self.redis_object(key)
        obj.delete
    end
end

DataStore.init

# %%
# DataStore.set("all_pools",all_pools)
# Out:
# [{:pool=>"0xe931b03260b2854e77e8da8378a1bc017b13cb97", :token0=>"1INCH", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.01, :cex_fee=>0.0003}, {:pool=>"0xd35efae4097d005720608eaf37e42a5936c94b44", :token0=>"1INCH", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.003, :cex_fee=>0.0003}, {:pool=>"0x9febc984504356225405e26833608b17719c82ae", :token0=>"1INCH", :token1=>"USDC", :token0_decimal=>18, :token1_decimal=>6, :dex_fee=>0.01, :cex_fee=>0.0003}, {:pool=>"0x1353fe67fff8f376762b7034dc9066f0be15a723", :token0=>"AAVE", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.01, :cex_fee=>0.0003}, {:pool=>"0x5ab53ee1d50eef2c1dd3d5402789cd27bb52c1bb", :token0=>"AAVE", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.003, :cex_fee=>0.0003}, {:pool=>"0xeb4626c5149894022c2066120ea7f20f217995fb", :token0=>"ETH", :token1=>"ACH", :token0_decimal=>18, :token1_decimal=>8, :dex_fee=>0.01, :cex_fee=>0.0003}, {:pool=>"0
# ...

# %%
def calc_swap_log(logs)
    return if logs["event_name"]!="Swap"

    amount0 = logs["args"]["amount0"]
    amount1 = logs["args"]["amount1"]
    return {tick:logs["args"]["tick"],amount0: amount0<0 ? 0 : amount0 ,amount1: amount1<0 ? 0 : amount1}
end

def calc_swap(block)
    data= block["data"]["logs"].map {|x| calc_swap_log(x) }
    return {} if data==[]
    {id:block["id"],block_number:block["block_number"],tick:data[-1][:tick], volume0:data.map {|x| x[:amount0]}.sum,volume1:data.map {|x| x[:amount1]}.sum }
end

class Pool
   attr_accessor :init_tick, :pool

    def initialize()
        self.pool = []
        self.init_tick = nil
    end
end


def calc_pool_log(logs,pool,id,block_number)
    if logs["event_name"]=="Initialize" then
        pool.init_tick = logs["args"]["tick"]
        return 
    end

    if logs["event_name"]=="IncreaseLiquidity" then
        pool.pool.push ({:id=>id,
                         :pool_id => logs["args"]["tokenId"],
                         :block_number=>block_number,
                         :amount0=>logs["args"]["amount0"],
                         :amount1=>logs["args"]["amount1"],
                         :liquidity=>logs["args"]["liquidity"]})
    end
    if logs["event_name"]=="DecreaseLiquidity" then
        pool.pool.push ({:id=>id,
                         :pool_id => logs["args"]["tokenId"],
                         :block_number=>block_number,
                         :amount0=>-logs["args"]["amount0"],
                         :amount1=>-logs["args"]["amount1"],
                         :liquidity=>-logs["args"]["liquidity"]})
    end
end

def calc_pool(block,pool)
    data= block["data"]["logs"].map {|x| calc_pool_log(x,pool,block["id"],block["block_number"]) }
end
# Out:
# :calc_pool

# %%
# all_pools = all_pools[210,10]

# %%
pool = "0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf"
po = DataStore.get("uniswap.#{pool}.pool")
sw = DataStore.get("uniswap.#{pool}.swap")
ta = DataStore.get("uniswap.#{pool}.time_table")
nil

# %%
puts po[0,100].pretty_inspect
# Out:
# [{:id=>0,
#   :pool_id=>204879,
#   :block_number=>14403763,
#   :amount0=>0,
#   :amount1=>10000000000000000000,
#   :liquidity=>7.942607912996183e+21},
#  {:id=>1,
#   :pool_id=>204887,
#   :block_number=>14403829,
#   :amount0=>0,
#   :amount1=>250000000000000000,
#   :liquidity=>22906967063389590000},
#  {:id=>2,
#   :pool_id=>204890,
#   :block_number=>14403875,
#   :amount0=>0,
#   :amount1=>200000000000000000,
#   :liquidity=>18168196741026672217},
#  {:id=>15,
#   :pool_id=>204879,
#   :block_number=>14404005,
#   :amount0=>0,
#   :amount1=>5000000000000000000,
#   :liquidity=>3.9713039564980916e+21},
#  {:id=>16,
#   :pool_id=>204879,
#   :block_number=>14404006,
#   :amount0=>0,
#   :amount1=>5000000000000000000,
#   :liquidity=>3.9713039564980916e+21},
#  {:id=>17,
#   :pool_id=>204879,
#   :block_number=>14404016,
#   :amount0=>0,
#   :amount1=>5000000000000000000,
#   :liquidity=>3.9713039564980916e+21},
#  {:id=>19,
#   :pool_id=>204879,
#   :block_number=>14404034,
# ...

# %%
puts sw[69000,100].pretty_inspect
# Out:
# [{:id=>125972,
#   :block_number=>14692503,
#   :tick=>-50976,
#   :volume0=>0,
#   :volume1=>27323317141474960000},
#  {:id=>125974,
#   :block_number=>14692505,
#   :tick=>-50979,
#   :volume0=>730000000000000000000,
#   :volume1=>0},
#  {:id=>125976,
#   :block_number=>14692506,
#   :tick=>-50984,
#   :volume0=>1119519958584012700000,
#   :volume1=>0},
#  {:id=>125977,
#   :block_number=>14692509,
#   :tick=>-50989,
#   :volume0=>1.2208807075727506e+21,
#   :volume1=>0},
#  {:id=>125979,
#   :block_number=>14692512,
#   :tick=>-50991,
#   :volume0=>622440674302300650000,
#   :volume1=>0},
#  {:id=>125980,
#   :block_number=>14692514,
#   :tick=>-50992,
#   :volume0=>305190000000000000000,
#   :volume1=>0},
#  {:id=>125982,
#   :block_number=>14692515,
#   :tick=>-50995,
#   :volume0=>612934481700000000000,
#   :volume1=>0},
#  {:id=>125987,
#   :block_number=>14692516,
#   :tick=>-51049,
#   :volume0=>1.6478341965108113e+22,
#   :volume1=>23000000000000000000},
#  {:id=>125988,
# ...

# %%
ta.last
# Out:
# [14692554, 1651416105, "2022-05-01 14:41"]

# %%
(0..all_pools.size-1).each do |cp|
  cur_pool=all_pools[cp]
  puts "#{cp}/#{all_pools.size} #{cur_pool}"

    pool = cur_pool[:pool]
    endpoint = "https://uniswap.funji.club/api/v1/uni/txn/"

    data = []
    last_id = 0

    loop do
        puts last_id

        conn = Faraday.new( url: endpoint+pool+"?page_size=500&last_id="+last_id.to_s )
        response = conn.get() do |req|
            req["Authorization"] = "Bearer ff691328bb4547dcb5517baa23ab75c6"
        end

        slice = JSON.parse(response.body)["data"]
        
        break if slice.size==0

        data = data + slice
        
        last_id = slice[-1]["id"]
    end

    data = data.map.with_index {|x,i| x["id"]=i; x }

    timetable = data.map {|x| [x["block_number"],x["data"]["subgraph"]["timestamp"],Time.at(x["data"]["subgraph"]["timestamp"]).to_s[0,16]] }
    
    swap_data = data.deep_dup
    swap_data = swap_data.map {|x| x['data']['logs'] = x['data']['logs'].filter {|y| ["Swap"].include?( y['event_name']) }; x["input"]=""; x["subgraph"]={}; x}
    swap_data = swap_data.map {|x| calc_swap(x) }.filter {|x| x.has_key?(:tick) }

    swap_data.push({block_number:-1})

    swap = []
    acc_volume0=0
    acc_volume1=0

    (0..swap_data.size-2).each do |i|
        if swap_data[i][:block_number]==swap_data[i+1][:block_number] then
            acc_volume0 += swap_data[i][:volume0]
            acc_volume1 += swap_data[i][:volume1]
        else
            swap.push({
                :id=>swap_data[i][:id],
                :block_number=>swap_data[i][:block_number],
                :tick=>swap_data[i][:tick],
                :volume0=>swap_data[i][:volume0]+acc_volume0,
                :volume1=>swap_data[i][:volume1]+acc_volume1,
            })
            acc_volume0 = 0 
            acc_volume1 = 0

        end
        
    end


    pool = Pool.new

    pool_data = data.deep_dup
    pool_data = pool_data.map {|x| x['data']['logs'] = x['data']['logs'].filter {|y| ["Initialize","IncreaseLiquidity","DecreaseLiquidity"].include?( y['event_name']) }; x["input"]=""; x["subgraph"]={}; x}
    pool_data_process = pool_data.map {|x| ret=calc_pool(x,pool); }


    DataStore.set("uniswap.#{cur_pool[:pool]}",cur_pool)
    DataStore.set("uniswap.#{cur_pool[:pool]}.pool",pool.pool)
    DataStore.set("uniswap.#{cur_pool[:pool]}.swap",swap)
    DataStore.set("uniswap.#{cur_pool[:pool]}.init_tick",pool.init_tick)
    DataStore.set("uniswap.#{cur_pool[:pool]}.time_table",timetable)

    puts " uniswap.#{cur_pool[:pool]} - #{JSON.dump(cur_pool).size} "
    puts " uniswap.#{cur_pool[:pool]}.pool - #{JSON.dump(pool.pool).size} "
    puts " uniswap.#{cur_pool[:pool]}.swap - #{JSON.dump(swap).size} "
    puts " uniswap.#{cur_pool[:pool]}.init_tick - #{JSON.dump(pool.init_tick).size} "
    puts " uniswap.#{cur_pool[:pool]}.time_table - #{JSON.dump(timetable).size} "
    nil
end
# Out:
# 0/213 {:pool=>"0x3b685307c8611afb2a9e83ebc8743dc20480716e", :token0=>"FTM", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.01, :cex_fee=>0.0003}
# 0
# 1266536
# 1267036
# 1267536
# 1268036
# 1268536
# 1269036
# 1269536
# 1270036
# 1270536
# 1271036
# 1271536
# 1272036
# 1272536
# 1273036
# 1273536
# Interrupt:
# /usr/local/lib/ruby/2.7.0/net/protocol.rb:217:in `wait_readable'
# /usr/local/lib/ruby/2.7.0/net/protocol.rb:217:in `rbuf_fill'
# /usr/local/lib/ruby/2.7.0/net/protocol.rb:191:in `readuntil'
# /usr/local/lib/ruby/2.7.0/net/protocol.rb:201:in `readline'
# /usr/local/lib/ruby/2.7.0/net/http/response.rb:322:in `read_chunked'
# /usr/local/lib/ruby/2.7.0/net/http/response.rb:292:in `block in read_body_0'
# /usr/local/lib/ruby/2.7.0/net/http/response.rb:270:in `inflater'
# /usr/local/lib/ruby/2.7.0/net/http/response.rb:290:in `read_body_0'
# /usr/local/lib/ruby/2.7.0/net/http/response.rb:210:in `read_body'
# ...

# %%
puts " uniswap.#{cur_pool[:pool]} - #{JSON.dump(cur_pool).size} "
puts " uniswap.#{cur_pool[:pool]}.pool - #{JSON.dump(pool.pool).size} "
puts " uniswap.#{cur_pool[:pool]}.swap - #{JSON.dump(swap).size} "
puts " uniswap.#{cur_pool[:pool]}.init_tick - #{JSON.dump(pool.init_tick).size} "
puts " uniswap.#{cur_pool[:pool]}.time_table - #{JSON.dump(timetable).size} "
# Out:
#  uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07 - 157
#  uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.pool - 517
#  uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.swap - 2357
#  uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.init_tick - 7
#  uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.time_table - 1354

# %%
DataStore.get("uniswap.0x27e688afe58efedb3d98cd787a9a7586f8730f58.time_table")
# Out:
# [[14241314, 1645338198, "2022-02-20 06:23"], [14241703, 1645343490, "2022-02-20 07:51"], [14241704, 1645343527, "2022-02-20 07:52"], [14241706, 1645343536, "2022-02-20 07:52"], [14241707, 1645343544, "2022-02-20 07:52"], [14241707, 1645343544, "2022-02-20 07:52"], [14241710, 1645343598, "2022-02-20 07:53"], [14241726, 1645343825, "2022-02-20 07:57"], [14241813, 1645345200, "2022-02-20 08:20"], [14241814, 1645345280, "2022-02-20 08:21"], [14241816, 1645345293, "2022-02-20 08:21"], [14241839, 1645345578, "2022-02-20 08:26"], [14241841, 1645345615, "2022-02-20 08:26"], [14241903, 1645346442, "2022-02-20 08:40"], [14241933, 1645346767, "2022-02-20 08:46"], [14241940, 1645346825, "2022-02-20 08:47"], [14241946, 1645346854, "2022-02-20 08:47"], [14241946, 1645346854, "2022-02-20 08:47"], [14241974, 1645347248, "2022-02-20 08:54"], [14241974, 1645347248, "2022-02-20 08:54"], [14241984, 1645347383, "2022-02-20 08:56"], [14241987, 1645347404, "2022-02-20 08:56"], [14242021, 1645347934, "2022-
# ...

# %%
puts pool.pool.pretty_inspect
# Out:
# [{:id=>0,
#   :pool_id=>54189,
#   :block_number=>12669150,
#   :amount0=>1.5508296858936413e+21,
#   :amount1=>5432843983,
#   :liquidity=>23666466165925576},
#  {:id=>16,
#   :pool_id=>54189,
#   :block_number=>12671599,
#   :amount0=>599999999763607700000,
#   :amount1=>928937213,
#   :liquidity=>8377056943666126},
#  {:id=>27,
#   :pool_id=>54189,
#   :block_number=>12673318,
#   :amount0=>-2.055348294746146e+21,
#   :amount1=>-8249699871,
#   :liquidity=>-32043523109591702},
#  {:id=>28,
#   :pool_id=>55210,
#   :block_number=>12675220,
#   :amount0=>5999999999999982,
#   :amount1=>0,
#   :liquidity=>54018832821532}]

# %%
DataStore.set("uniswap.#{cur_pool[:pool]}",cur_pool)
DataStore.set("uniswap.#{cur_pool[:pool]}.pool",pool.pool)
DataStore.set("uniswap.#{cur_pool[:pool]}.swap",swap)
DataStore.set("uniswap.#{cur_pool[:pool]}.init_tick",pool.init_tick)
DataStore.set("uniswap.#{cur_pool[:pool]}.time_table",timetable)
# Out:
# [[12669150, 1624163718, "2021-06-20 04:35"], [12669666, 1624170887, "2021-06-20 06:34"], [12669679, 1624171092, "2021-06-20 06:38"], [12669774, 1624172404, "2021-06-20 07:00"], [12670024, 1624175773, "2021-06-20 07:56"], [12670071, 1624176415, "2021-06-20 08:06"], [12670132, 1624177227, "2021-06-20 08:20"], [12670286, 1624179143, "2021-06-20 08:52"], [12670483, 1624181921, "2021-06-20 09:38"], [12670649, 1624184067, "2021-06-20 10:14"], [12670770, 1624185669, "2021-06-20 10:41"], [12670994, 1624188731, "2021-06-20 11:32"], [12671059, 1624189691, "2021-06-20 11:48"], [12671059, 1624189691, "2021-06-20 11:48"], [12671156, 1624191209, "2021-06-20 12:13"], [12671489, 1624195806, "2021-06-20 13:30"], [12671599, 1624197362, "2021-06-20 13:56"], [12671809, 1624200698, "2021-06-20 14:51"], [12672294, 1624207050, "2021-06-20 16:37"], [12672346, 1624207675, "2021-06-20 16:47"], [12672371, 1624208025, "2021-06-20 16:53"], [12672486, 1624209560, "2021-06-20 17:19"], [12672490, 1624209625, "2021-
# ...

# %%
puts cur_pool
# Out:
# {:pool=>"0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07", :token0=>"UNI", :token1=>"USDT", :token0_decimal=>18, :token1_decimal=>6, :dex_fee=>0.0005, :cex_fee=>0.0003}

# %%
DataStore.get("uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07")
# Out:
# {:pool=>"0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07", :token0=>"UNI", :token1=>"USDT", :token0_decimal=>18, :token1_decimal=>6, :dex_fee=>0.0005, :cex_fee=>0.0003}

# %%
DataStore.get("uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.pool")
# Out:
# [{:id=>0, :pool_id=>54189, :block_number=>12669150, :amount0=>1.5508296858936413e+21, :amount1=>5432843983, :liquidity=>23666466165925576}, {:id=>16, :pool_id=>54189, :block_number=>12671599, :amount0=>599999999763607700000, :amount1=>928937213, :liquidity=>8377056943666126}, {:id=>27, :pool_id=>54189, :block_number=>12673318, :amount0=>-2.055348294746146e+21, :amount1=>-8249699871, :liquidity=>-32043523109591702}, {:id=>28, :pool_id=>55210, :block_number=>12675220, :amount0=>5999999999999982, :amount1=>0, :liquidity=>54018832821532}]

# %%
DataStore.get("uniswap.0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf.swap")[-1]
# Out:
# {:id=>65507, :block_number=>14641391, :tick=>-51950, :volume0=>4.1236744015241685e+21, :volume1=>0}

# %%
1.0001**-51950
# Out:
# 0.005545656516208479

# %%
DataStore.get("uniswap.0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf")
# Out:
# {:pool=>"0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf", :token0=>"APE", :token1=>"ETH", :token0_decimal=>18, :token1_decimal=>18, :dex_fee=>0.003, :cex_fee=>0.0003}

# %%
DataStore.get("uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.init_tick")
# Out:
# -246366

# %%
DataStore.get("uniswap.0x36f7273afb18a3f2fdd07e3ac1c28e65d7ea8f07.time_table")
# Out:
# [[12669150, 1624163718, "2021-06-20 04:35"], [12669666, 1624170887, "2021-06-20 06:34"], [12669679, 1624171092, "2021-06-20 06:38"], [12669774, 1624172404, "2021-06-20 07:00"], [12670024, 1624175773, "2021-06-20 07:56"], [12670071, 1624176415, "2021-06-20 08:06"], [12670132, 1624177227, "2021-06-20 08:20"], [12670286, 1624179143, "2021-06-20 08:52"], [12670483, 1624181921, "2021-06-20 09:38"], [12670649, 1624184067, "2021-06-20 10:14"], [12670770, 1624185669, "2021-06-20 10:41"], [12670994, 1624188731, "2021-06-20 11:32"], [12671059, 1624189691, "2021-06-20 11:48"], [12671059, 1624189691, "2021-06-20 11:48"], [12671156, 1624191209, "2021-06-20 12:13"], [12671489, 1624195806, "2021-06-20 13:30"], [12671599, 1624197362, "2021-06-20 13:56"], [12671809, 1624200698, "2021-06-20 14:51"], [12672294, 1624207050, "2021-06-20 16:37"], [12672346, 1624207675, "2021-06-20 16:47"], [12672371, 1624208025, "2021-06-20 16:53"], [12672486, 1624209560, "2021-06-20 17:19"], [12672490, 1624209625, "2021-
# ...

# %%
DataStore.get("uniswap.0xe931b03260b2854e77e8da8378a1bc017b13cb97.swap")
# Out:
# NameError: uninitialized constant DataStore
# (irb):in `irb_binding'

# %%
-----------------

# %%
#data verify

# %%
pool = "0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf"
endpoint = "https://uniswap.funji.club/api/v1/uni/txn/"

data = []
last_id = 0

loop do
    puts last_id

    conn = Faraday.new( url: endpoint+pool+"?page_size=2000&last_id="+last_id.to_s )
    response = conn.get() do |req|
        req["Authorization"] = "Bearer ff691328bb4547dcb5517baa23ab75c6"
    end

    slice = JSON.parse(response.body)["data"]
    
    break if slice.size==0

    data = data + slice
    
    last_id = slice[-1]["id"]
end
# Out:
# 0
# 4586591
# 4588852
# 4590852
# 4592852
# 4594852
# 4596852
# 4598852
# 4600852
# 4602852
# 4604852
# 4606852
# 4608852
# 4610852
# 4612852
# 4614852
# 4616852
# 4618852
# 4620852
# 4622852
# 4624852
# 4626852
# 4628852
# 4630852
# 4632852
# 4634852
# 4636852
# 4638852
# 4640852
# 4642852
# 4644852
# 4646852
# 4648852
# 5549765
# 5551765
# 5553765
# 5555765
# 5557765
# 5559765
# 5561765
# 5563765
# 5565765
# 5567765
# 5569765
# 5571765
# 5573765
# 5575765
# 5577765
# 5579785
# 5581785
# 5583785
# 5585785
# 5587785
# 5589785
# 5591785
# 5593785
# 5595785
# 5597785
# 5599785
# 5601785
# 5603785
# 5605785
# 5723210
# 5725210
# 5725262

# %%
data.last
# Out:
# {"id"=>5725262, "pool"=>"0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf", "block_number"=>14692554, "data"=>{"block_number"=>14692554, "from"=>"0x6b01bF395d84A0815c130A46cFA28bdEea4922aA", "input"=>"...", "logs"=>[{"args"=>{"amount0"=>229000000000000000000, "amount1"=>-1354846515417539315, "liquidity"=>2.5237606311715263e+23, "recipient"=>"0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45", "sender"=>"0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45", "sqrtPriceX96"=>6.10301138411494e+27, "tick"=>-51274}, "emitter"=>"Pool", "event_name"=>"Swap"}], "subgraph"=>{"amount0"=>229, "amount1"=>-1.3548465154175393, "id"=>"0xb39a5d4b3ff48c71f5ce7cc1a4babcb7e16f9585a8847397d65e23f66ced19ae#127181", "sqrtPriceX96"=>6.10301138411494e+27, "tick"=>-51274, "timestamp"=>1651416105}, "to"=>"0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45", "txn_hash"=>"0xb39a5d4b3ff48c71f5ce7cc1a4babcb7e16f9585a8847397d65e23f66ced19ae", "txn_index"=>293, "value"=>0}}

# %% [markdown]
# ![Picture title](image-20220501-233954.png)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ebde59c2-d67b-4e31-ad3b-1bdd07014691' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
