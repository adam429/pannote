# %%
# load init moudle file

load "/work/pannote/panbot_note.rb"
nil

# %%
address = '0xfe0693ee9174e1d156942b3aa64348dd45962dfb'
# Out:
# "0xfe0693ee9174e1d156942b3aa64348dd45962dfb"

# %%
exclude = {}
exclude.merge! Address.where("tag LIKE ?","%Hot Wallet%").select(:addr).map {|x| [x.addr,true]}.to_h
exclude.merge! Address.where("tag LIKE ?","%Bridge%").select(:addr).map {|x| [x.addr,true]}.to_h
exclude.merge! Address.where(is_contract:true).select(:addr).map {|x| [x.addr,true]}.to_h

level =  []
level << [{address=>address}]
# Out:
# [[{"0xfe0693ee9174e1d156942b3aa64348dd45962dfb"=>"0xfe0693ee9174e1d156942b3aa64348dd45962dfb"}]]

# %%
time = Time.now

puts saved_count = level.last.count 
level << address_graph_expand(level.last,exclude)

puts level.last.count
puts Time.now-time
# Out:
# 1
# 3
# 0.4495919

# %%
# output connection detail
time = Time.now

addr_map = {}
level_addr = level.map {|addr| addr.map {|x| x.to_a[0][1]}.uniq}
level_addr.each_with_index {|obj,i|
  cur_map = (obj.map {|x| [x,i] }.to_h)
  addr_map.merge!(cur_map ) {|key, oldval, newval| oldval }
}


puts Parallel.map(level.last.map {|x| x.map {|k,v| v}}.uniq, in_threads: 10) {|x|
  addr = Address.find_by_addr(x); }.filter {|x| x!=nil }
  .map { |addr|  [addr.addr+"["+addr_map[addr.addr].to_s+"]", addr.tag, Transfer.where(from:addr.addr).group(:to).count.count, Transfer.where(to:addr.addr).group(:from).count.count, addr.is_panbot]
}.sort {|x,y| -1*((x[2]+x[3])<=>(y[2]+y[3]))}.map {|x| x.join("-") }[0,200].join("\n")

puts Time.now-time
# Out:
# 0x393a0ef293ae6d8c11f49744b081ddd343debbd0[1]--0-393-false
# 0xfe0693ee9174e1d156942b3aa64348dd45962dfb[0]--22-4-true
# 0xfc4ad7dbf8c22d9b51e659f060934a4d38659d2d[1]--3-1-
# 0.669668732

# %%
to_graph(level.last,level,5,100,true)
# addr_list=level[2].map {|x| x.to_a[0][1]}.uniq
# min_amount = 100
# Transfer.where(from:addr_list).where('"to"<>\'0x18b2a687610328590bc8f2e5fedde3b582a49cda\'').where("amount > ?",min_amount * 1e18).map {|x|
#     %Q( "#{x.ar_from.tag ? x.ar_from.tag + ' @'+x.from[-4,4] : x.from }" -> "#{ x.ar_to.tag ? x.ar_to.tag + ' @'+x.to[-4,4] : x.to}" [label=#{(x.amount/1e18).round(2)}]  ) +";\n" +
#     %Q( "#{x.ar_from.tag ? x.ar_from.tag + ' @'+x.from[-4,4] : x.from }" [style=filled color=1}]  )  +";\n" +
#     %Q( "#{ x.ar_to.tag ? x.ar_to.tag + ' @'+x.to[-4,4] : x.to}" [style=filled color=2}]  )  +";\n" 
# }.join("") + "\n}"
# Out:
# "<html>\r\n<head><title>414 Request-URI Too Large</title></head>\r\n<body>\r\n<center><h1>414 Request-URI Too Large</h1></center>\r\n<hr><center>cloudflare</center>\r\n</body>\r\n</html>\r\n"

# %%
auto_tag(animals,level.last)
# Out:
# pony
# panbot_account_list.count = 11
# money_account_list.count = 2
# ["0x1b08267358fd447b0fcb4dad9094d8200a999f97", "0xb17bade91ec5940780551e76e2bc3c8df1fdc12a"]

# %%
# Out:
# :auto_tag

# %%
#------ auto tag -----

# %%
## clear all the animal tag

#puts Address.where('tag is not null').filter {|x| animals.include?(x.tag.split(" ")[0]) }.map{|x| x.tag=nil ;x.save}
# Out:
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# ...

# %%
animals = [
  "aardvark",
  "albatross",
  "alligator",
  "alpaca",
  "ant",
  "anteater",
  "antelope",
  "ape",
  "armadillo",
  "baboon",
  "badger",
  "barracuda",
  "bat",
  "bear",
  "beaver",
  "bee",
  "bison",
  "boar",
  "buffalo",
  "butterfly",
  "camel",
  "capybara",
  "caribou",
  "cassowary",
  "cat",
  "caterpillar",
  "cattle",
  "chamois",
  "cheetah",
  "chicken",
  "chimpanzee",
  "chinchilla",
  "chough",
  "clam",
  "cobra",
  "cockroach",
  "cod",
  "cormorant",
  "coyote",
  "crab",
  "crane",
  "crocodile",
  "crow",
  "curlew",
  "deer",
  "dinosaur",
  "dog",
  "dogfish",
  "dolphin",
  "donkey",
  "dotterel",
  "dove",
  "dragonfly",
  "duck",
  "dugong",
  "dunlin",
  "eagle",
  "echidna",
  "eel",
  "eland",
  "elephant",
  "elephant-seal",
  "elk",
  "emu",
  "falcon",
  "ferret",
  "finch",
  "fish",
  "flamingo",
  "fly",
  "fox",
  "frog",
  "gaur",
  "gazelle",
  "gerbil",
  "giant-panda",
  "giraffe",
  "gnat",
  "gnu",
  "goat",
  "goose",
  "goldfinch",
  "goldfish",
  "gorilla",
  "goshawk",
  "grasshopper",
  "grouse",
  "guanaco",
  "guinea-fowl",
  "guinea-pig",
  "gull",
  "hamster",
  "hare",
  "hawk",
  "hedgehog",
  "heron",
  "herring",
  "hippopotamus",
  "hornet",
  "horse",
  "human",
  "hummingbird",
  "hyena",
  "ibex",
  "ibis",
  "jackal",
  "jaguar",
  "jay",
  "jellyfish",
  "kangaroo",
  "kingfisher",
  "koala",
  "komodo-dragon",
  "kookabura",
  "kouprey",
  "kudu",
  "lapwing",
  "lark",
  "lemur",
  "leopard",
  "lion",
  "llama",
  "lobster",
  "locust",
  "loris",
  "louse",
  "lyrebird",
  "magpie",
  "mallard",
  "manatee",
  "mandrill",
  "mantis",
  "marten",
  "meerkat",
  "mink",
  "mole",
  "mongoose",
  "monkey",
  "moose",
  "mouse",
  "mosquito",
  "mule",
  "narwhal",
  "newt",
  "nightingale",
  "octopus",
  "okapi",
  "opossum",
  "oryx",
  "ostrich",
  "otter",
  "owl",
  "ox",
  "oyster",
  "panther",
  "parrot",
  "partridge",
  "peafowl",
  "pelican",
  "penguin",
  "pheasant",
  "pig",
  "pigeon",
  "polar-bear",
  "pony",
  "porcupine",
  "porpoise",
  "prairie-dog",
  "quail",
  "quelea",
  "quetzal",
  "rabbit",
  "raccoon",
  "rail",
  "ram",
  "rat",
  "raven",
  "red-deer",
  "red-panda",
  "reindeer",
  "rhinoceros",
  "rook",
  "salamander",
  "salmon",
  "sand-dollar",
  "sandpiper",
  "sardine",
  "scorpion",
  "sea-lion",
  "sea-urchin",
  "seahorse",
  "seal",
  "shark",
  "sheep",
  "shrew",
  "skunk",
  "snail",
  "snake",
  "sparrow",
  "spider",
  "spoonbill",
  "squid",
  "squirrel",
  "starling",
  "stingray",
  "stinkbug",
  "stork",
  "swallow",
  "swan",
  "tapir",
  "tarsier",
  "termite",
  "toad",
  "trout",
  "turkey",
  "turtle",
  "vicuña",
  "viper",
  "vulture",
  "wallaby",
  "walrus",
  "wasp",
  "water-buffalo",
  "weasel",
  "wolf",
  "wolverine",
  "wombat",
  "woodcock",
  "woodpecker",
  "worm",
  "wren",
  "yak",
  "zebra"
].sort {|x,y| x.reverse<=>y.reverse} + ["tiger","whale"]
# Out:
# ["alpaca", "red-panda", "giant-panda", "barracuda", "quelea", "koala", "chinchilla", "gorilla", "llama", "echidna", "hyena", "capybara", "zebra", "cobra", "kookabura", "vicuña", "crab", "toad", "squid", "eland", "cod", "mallard", "leopard", "lyrebird", "hummingbird", "bee", "manatee", "chimpanzee", "giraffe", "partridge", "magpie", "snake", "nightingale", "eagle", "crocodile", "gazelle", "mole", "turtle", "cattle", "mule", "crane", "sardine", "porcupine", "wolverine", "ape", "antelope", "hare", "vulture", "porpoise", "goose", "mongoose", "moose", "horse", "seahorse", "louse", "mouse", "grouse", "termite", "coyote", "dove", "wolf", "pig", "guinea-pig", "starling", "herring", "lapwing", "dugong", "dog", "prairie-dog", "hedgehog", "frog", "stinkbug", "cheetah", "cockroach", "ostrich", "finch", "goldfinch", "chough", "fish", "goldfish", "dogfish", "jellyfish", "okapi", "yak", "woodcock", "duck", "elk", "mink", "skunk", "rook", "shark", "lark", "aardvark", "stork", "hawk", "goshawk", "sea
# ...

# %%
all = Address.where(is_panbot:true).count
tag = Address.where(is_panbot:true).where('tag is not null').count

puts "[all] tag panbot = #{tag}  all panbot = #{all}  tag_ratio = #{ (tag*100/all.to_f).round(2) }%"

all = Address.where("return_amt is not null").order(return_amt: :desc).limit(500).where(is_panbot:true).count
tag = Address.where("return_amt is not null").order(return_amt: :desc).limit(500).where(is_panbot:true).all.filter {|x| x.tag!=nil}.count

puts "[top500] tag panbot = #{tag}  all panbot = #{all}  tag_ratio = #{ (tag*100/all.to_f).round(2) }%"
puts
# Out:
# [all] tag panbot = 3049  all panbot = 72929  tag_ratio = 4.18%
# [top500] tag panbot = 256  all panbot = 500  tag_ratio = 51.2%

# %%
exclude = {}
exclude.merge! Address.where("tag LIKE ?","%Hot Wallet%").select(:addr).map {|x| [x.addr,true]}.to_h
exclude.merge! Address.where("tag LIKE ?","%Bridge%").select(:addr).map {|x| [x.addr,true]}.to_h
exclude.merge! Address.where(is_contract:true).select(:addr).map {|x| [x.addr,true]}.to_h

top_addr = Address.where("return_amt is not null").order(return_amt: :desc).limit(500).reverse.to_a

# top_addr = Address.where("return_amt is not null").order(return_amt: :asc).limit(20).reverse.to_a
# top_addr = Address.where("avg_last_block_order <> ?",Float::NAN).order(avg_last_block_order: :asc).limit(200).reverse.to_a
# top_addr = Address.where("invest_cnt is not null").order(invest_cnt: :desc).limit(20).reverse.to_a
# Out:
# [#<Address id: 769022, addr: "0x34ed728aa106344f95a5381830427ab775e15191", is_contract: false, contract_abi: nil, is_panbot: true, bet_cnt_daily: nil, bet_epoch_cnt: 61, invest_cnt: 59, bet_cnt: 62, bet_bull_cnt: 26, bet_bear_cnt: 36, avg_bet_amt: 0.46824979023306673, bet_amt: "[0.2717538290464857,0.3047599278732944,0.144291628...", right_bet_ratio: 0.8548387096774194, win_bet_ratio: 0.532258064516129, invest_amt: 27.62673762375094, return_amt: 7.512139338628181, created_at: "2022-02-06 19:47:40.532099000 +0000", updated_at: "2022-02-16 17:35:11.716794000 +0000", tag: "cormorant bot 168", avg_last_block_order: 1.0169491525423728>, #<Address id: 811827, addr: "0x7093f9b180e6c6950ccd17c005f174855d79fa11", is_contract: false, contract_abi: nil, is_panbot: true, bet_cnt_daily: nil, bet_epoch_cnt: 10, invest_cnt: 10, bet_cnt: 10, bet_bull_cnt: 5, bet_bear_cnt: 5, avg_bet_amt: 4.056201426907397, bet_amt: "[2.654579207920792,5.0,4.205686274509804,4.2473267...", right_bet_ratio: 0.0, win_bet
# ...

# %%
200.times { |i|
    cur_addr = Address.find_by_addr(top_addr.pop.addr)
    puts "#{i} #{cur_addr.addr}  #{cur_addr.tag}"

    if cur_addr.tag==nil then

        level =  []
        level << [{cur_addr.addr=>cur_addr.addr}]

        loop do
            saved_count = level.last.count 
            level << address_graph_expand(level.last,exclude)
            puts "level=#{level.size} #{level.last.count}"
            break if saved_count == level.last.count 
            break if level.last.count > 3000
        end

        if level.last.count <=3000 then
            auto_tag(animals,level.last)
            # to_graph(level.last,level,5,100,true)
        end
    end
}
# Out:
# 0 0xfcbe1b9a24127fdcf915cbcb351d4f63724fa248  whale bot 2261
# 1 0x54870bfc2b65fc4a4766e60aeccf50537fc48241  tiger bot 1
# 2 0x498a5dd28eb31ef0758810af39f438247b58fc59  whale bot 2258
# 3 0x3e5126c8dd68db20246e51bc31cb087a28003d2e
# level=2 55
# level=3 229
# level=4 656
# level=5 4447
# 4 0x63601e212e97d3291999ecea62ba0b8e88d52166  cassowary bot 1
# 5 0xf9438fba1c614df061c07bbe30fc419eef462c2f  whale bot 2257
# 6 0xcd5a4c387ec161c1489d72a6f989c950b72ba55e  whale bot 859
# 7 0xae9ddbbb9c6879ef0660ece3ac30d6e21bfdd8ce  pony bot 10
# 8 0xb4eef1e7c6e571d088e1b1e5b6dd7e2f66bea1dd  whale bot 576
# 9 0x9d97d26275269f050ed893e94085bf74a71519c3  whale bot 2247
# 10 0x3533d109ad6c79eec50706a2c56aefdddfa4ef57  whale bot 2259
# 11 0x89bb80b57a27fd30f00b47071c8344d9fca781e9  butterfly bot 0
# 12 0x5e071b4ff18b7616497111616a7dc71d350c889b  dragonfly bot 1
# 13 0x77f56855123e2399bc7b3f9e7c647b9c24c2950f  fly bot 3
# 14 0xefce36efcf3e13840634d71145caf850fe6b2e15  whale bot 154
# ...

# %%
#--------------------------

# %%
group_name = 'donkey'
# Out:
# "donkey"

# %%
group = Address.where("tag LIKE ?","#{group_name}%").map {|x| {"input"=>x.addr}}
to_graph(group,group,0,100,true)
# Out:
# "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"no\"?>\n<!DOCTYPE svg PUBLIC \"-//W3C//DTD SVG 1.1//EN\"\n \"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd\">\n<!-- Generated by graphviz version 2.40.1 (20161225.0304)\n -->\n<!-- Title: %0 Pages: 1 -->\n<svg width=\"192pt\" height=\"133pt\"\n viewBox=\"0.00 0.00 192.17 132.80\" xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">\n<g id=\"graph0\" class=\"graph\" transform=\"scale(1 1) rotate(0) translate(4 128.8)\">\n<title>%0</title>\n<polygon fill=\"#ffffff\" stroke=\"transparent\" points=\"-4,4 -4,-128.8 188.1687,-128.8 188.1687,4 -4,4\"/>\n<!-- CEX Money -->\n<g id=\"node1\" class=\"node\">\n<title>CEX Money</title>\n<ellipse fill=\"#ffffe5\" stroke=\"#ffffe5\" cx=\"92.0843\" cy=\"-106.8\" rx=\"60.2361\" ry=\"18\"/>\n<text text-anchor=\"middle\" x=\"92.0843\" y=\"-102.6\" font-family=\"Times,serif\" font-size=\"14.00\" fill=\"#000000\">CEX Money</text>\n</g>\n<!-- donkey bot 0 @26d3 -->\n<g
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ebde59c2-d67b-4e31-ad3b-1bdd07014691' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
